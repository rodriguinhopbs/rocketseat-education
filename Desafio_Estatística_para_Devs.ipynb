# %% [markdown]
# <a href="https://colab.research.google.com/github/rodriguinhopbs/rocketseat-education/blob/main/Desafio_Estat%C3%ADstica_para_Devs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Dicionário de faturamento
dict_faturamento = {
    'data_ref': [
        '2023-01-01',
        '2020-02-01',
        '2021-03-01',
        '2022-04-01',
        '2023-05-01',
        '2023-06-01',
        '2020-07-01',
        '2021-08-01',
        '2022-09-01',
        '2023-10-01',
        '2022-11-01',
        '2023-12-01',
        ],
    'valor': [
        400000,
        890000,
        760000,
        430000,
        920000,
        340000,
        800000,
        500000,
        200000,
        900000,
        570000,
        995000,
        ]
}

# %%
df_faturamento = pd.DataFrame.from_dict(dict_faturamento).sort_values(by='data_ref')

# %%
df_faturamento
# Out:
#       data_ref   valor
# 1   2020-02-01  890000
# 6   2020-07-01  800000
# 2   2021-03-01  760000
# 7   2021-08-01  500000
# 3   2022-04-01  430000
# 8   2022-09-01  200000
# 10  2022-11-01  570000
# 0   2023-01-01  400000
# 4   2023-05-01  920000
# 5   2023-06-01  340000
# 9   2023-10-01  900000
# 11  2023-12-01  995000

# %%
media_vendas = round(df_faturamento['valor'].mean(), 2)
media_vendas
# Out:
# np.float64(642083.33)

# %%
df_faturamento.plot.bar(x='data_ref', y='valor')#, rot=45)
plt.show()

# %%
df_faturamento.plot.line(x='data_ref', y='valor')
plt.show()
